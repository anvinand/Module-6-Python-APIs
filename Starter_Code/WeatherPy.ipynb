# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 628

# %%
# Set the API base URL and your API key
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Initialize counters
record_count = 1
set_count = 1

# Loop through all the cities to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city name
    city_url = f"{base_url}?q={city}&appid={weather_api_key}"

    # Add 1 to the record count
    record_count += 1

    # Make the API request
    response = requests.get(city_url)

    # Parse the JSON response
    city_weather = response.json()

    # Print the formatted JSON response
    print(json.dumps(city_weather, indent=4, sort_keys=True))
    print(city_url)
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -25.0319,
#         "lon": 46.9987
#     },
#     "dt": 1726682576,
#     "id": 1055433,
#     "main": {
#         "feels_like": 296.72,
#         "grnd_level": 1016,
#         "humidity": 83,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 296.19,
#         "temp_max": 296.19,
#         "temp_min": 296.19
#     },
#     "name": "T\u00f4lanaro",
#     "sys": {
#         "country": "MG",
#         "id": 2147,
#         "sunrise": 1726627547,
#         "sunset": 1726670794,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 9.26
#     }
# }
# ...

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}?q={city}&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        #Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Country": city_country,
                             "Date": city_date})       

   # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tolanaro
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | arkhangel'sk
# Processing Record 5 of Set 1 | ilulissat
# Processing Record 6 of Set 1 | wailua homesteads
# Processing Record 7 of Set 1 | reyes
# Processing Record 8 of Set 1 | saint-joseph
# Processing Record 9 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 10 of Set 1 | elk city
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | constantia
# Processing Record 13 of Set 1 | ciamis
# Processing Record 14 of Set 1 | radomyshl
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 17 of Set 1 | puerto natales
# Processing Record 18 of Set 1 | ardestan
# Processing Record 19 of Set 1 | ko pha ngan
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) 

# Show Record Count
city_data_df.count()
# Out:
# City          604
# Lat           604
# Lng           604
# Max Temp      604
# Humidity      604
# Cloudiness    604
# Wind Speed    604
# Country       604
# Date          604
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      tolanaro -25.0319   46.9987    296.19        83          20
# 1      waitangi -43.9535 -176.5597    281.38        88          96
# 2     adamstown -25.0660 -130.1015    293.64        82          10
# 3  arkhangel'sk  64.5401   40.5433    285.21       100          75
# 4     ilulissat  69.2167  -51.1000    276.16        81          75
#
#    Wind Speed Country        Date
# 0        9.26      MG  1726683315
# 1        3.58      NZ  1726683316
# 2        2.50      PN  1726683317
# 3        2.00      RU  1726683318
# 4        0.00      GL  1726683319

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities_ai.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities_ai.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            tolanaro -25.0319   46.9987    296.19        83          20
# 1            waitangi -43.9535 -176.5597    281.38        88          96
# 2           adamstown -25.0660 -130.1015    293.64        82          10
# 3        arkhangel'sk  64.5401   40.5433    285.21       100          75
# 4           ilulissat  69.2167  -51.1000    276.16        81          75
#
#          Wind Speed Country        Date
# City_ID
# 0              9.26      MG  1726683315
# 1              3.58      NZ  1726683316
# 2              2.50      PN  1726683317
# 3              2.00      RU  1726683318
# 4              0.00      GL  1726683319

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title(f"City Max Latitude vs. Temperature (2024-09-16)")

# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs. Humidity(2024-09-16)")

# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness

plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs. Cloudiness (2024-09-16)")

# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title(f"City Latitude vs. Wind Speed (2024-09-16)")

# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3             arkhangel'sk  64.5401   40.5433    285.21       100          75
# 4                ilulissat  69.2167  -51.1000    276.16        81          75
# 5        wailua homesteads  22.0669 -159.3780    299.59        84         100
# 8                 elk city  35.4120  -99.4043    305.14        48           0
# 10              constantia  44.1833   28.6500    289.65        60          78
#
#          Wind Speed Country        Date
# City_ID
# 3              2.00      RU  1726683318
# 4              0.00      GL  1726683319
# 5              6.69      US  1726683320
# 8              8.23      US  1726683325
# 10             5.04      RO  1726683327

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            tolanaro -25.0319   46.9987    296.19        83          20
# 1            waitangi -43.9535 -176.5597    281.38        88          96
# 2           adamstown -25.0660 -130.1015    293.64        82          10
# 6               reyes -14.3167  -67.3833    309.13        44           4
# 7        saint-joseph -21.3667   55.6167    293.36        81          40
#
#          Wind Speed Country        Date
# City_ID
# 0              9.26      MG  1726683315
# 1              3.58      NZ  1726683316
# 2              2.50      PN  1726683317
# 6              4.12      BO  1726683321
# 7              3.76      RE  1726683322

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Latitude vs. Max Temp")

slope, intercept, rvalue, pvalue, stderr = linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
x_values = np.array(northern_hemi_df["Lat"])
regress_values = intercept + slope * x_values

plt.plot(x_values, regress_values, "r-")
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.5522520828795477

# %%
# Linear regression on Southern Hemisphere

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Latitude vs. Max Temp")

plt.title(f"Latitude vs. Max Temp")

slope, intercept, rvalue, pvalue, stderr = linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
x_values = np.array(southern_hemi_df["Lat"])
regress_values = intercept + slope * x_values

plt.plot(x_values, regress_values, "r-")
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.5002506384225759

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear relationship between the latitude and Max temperature for the northern hemisphere is linear, which means that as the latitude increases (moving toward the poles) the temperature falls.
#
# We see a smilar trend/ or linear relatsionship in the Southern hemisphere, as the latitude decreases (moving towards the equator), the temperature rises.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Latitude vs. Max Temp")

slope, intercept, rvalue, pvalue, stderr = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
x_values = np.array(northern_hemi_df["Lat"])
regress_values = intercept + slope * x_values

plt.plot(x_values, regress_values, "r-")
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.0001623212904204248

# %%
# Southern Hemisphere

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Latitude vs. Max Temp")

plt.title(f"Latitude vs. Max Temp")

slope, intercept, rvalue, pvalue, stderr = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
x_values = np.array(southern_hemi_df["Lat"])
regress_values = intercept + slope * x_values

plt.plot(x_values, regress_values, "r-")
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.0023113777308424325

# %% [markdown]
# **Discussion about the linear relationship:**
# Both graphs show an almost negligible correlation between latitude and humidity in both the Northern and Southern Hemispheres.
# In the Northern hemisphere, we see a very slight negative correlation, meaning that the lattude does not significantly impact humidity.
# The Southern hemisphere slope of 0.01, means that latitude has almost no impact on humidity levels in this region.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Latitude vs. Max Temp")

slope, intercept, rvalue, pvalue, stderr = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
x_values = np.array(northern_hemi_df["Lat"])
regress_values = intercept + slope * x_values

plt.plot(x_values, regress_values, "r-")
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 1.327092843371424e-06

# %%
# Southern Hemisphere

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Latitude vs. Max Temp")

plt.title(f"Latitude vs. Max Temp")

slope, intercept, rvalue, pvalue, stderr = linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
x_values = np.array(southern_hemi_df["Lat"])
regress_values = intercept + slope * x_values

plt.plot(x_values, regress_values, "r-")
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.02337102466775205

# %% [markdown]
# **Discussion about the linear relationship:**
#
# In the Northern hemisphere the slope is -0.17 which shows a slight negative correlation between latitude and cloudiness. As latitude increases, cloudiness decreases slightly.
#
# The Southern hemisphere shows a stronger correlation between latitude and cloudiness compared to the Northern Hemisphere. As latitude increases (moving towards the equator), cloudiness tends to decrease at a more noticeable rate than in the Northern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Latitude vs. Max Temp")

slope, intercept, rvalue, pvalue, stderr = linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
x_values = np.array(northern_hemi_df["Lat"])
regress_values = intercept + slope * x_values

plt.plot(x_values, regress_values, "r-")
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.0004802934298690616

# %%
# Southern Hemisphere

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], edgecolor="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f"Latitude vs. Max Temp")

plt.title(f"Latitude vs. Max Temp")

slope, intercept, rvalue, pvalue, stderr = linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
x_values = np.array(southern_hemi_df["Lat"])
regress_values = intercept + slope * x_values

plt.plot(x_values, regress_values, "r-")
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.0320372484335082

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear relationship between the latitude and wind speed for the northern hemisphere is flat, which indicates
# that the latitude does not significantly affect wind speed.
# In the Southern hemisphere, the slope of is quite small, indicating a weak negative relationship between latitude and wind speed.
# This suggests that, on average, wind speeds decrease slightly as you approach the equator from southern latitudes.
